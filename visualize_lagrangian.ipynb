# %%
import numpy as np
stat = np.load("norm_stat.npy")
import matplotlib.pyplot as plt

# %%
mu, gamma, lag_mu, lag_gamma = stat

# %%
plt.plot(gamma[:,1])

# %%
plt.plot(lag_gamma[:,1])

# %%
stat_last = np.load("norm_stat_last.npy")
mu, gamma, lag_mu, lag_gamma = stat_last
gamma[:,1]
# Out:
# array([12.68497372, 14.59243774, 15.72974014, 15.56677055, 11.23933029,
#         8.90460205, 14.94807339, 13.05825233, 12.91922665, 15.33963203,
#        14.31454277, 15.65715122, 11.11752129, 10.74551392, 15.09698582,
#        14.91059685, 14.78725624, 13.58462906, 13.38205719, 10.04357719,
#        12.58592224, 12.42524242, 14.30479145, 13.60978794, 16.38707924,
#        20.11647034, 11.34120655, 15.64050865, 12.04067898, 10.59398651,
#        11.56692123, 15.35337067, 17.42485619, 14.44091129, 14.42316914,
#        13.66716862, 11.55004597, 16.22177124, 17.33176041, 14.38726521,
#        10.68593502, 12.89740086, 14.54022694, 11.77845001, 14.9141283 ,
#        24.27698898, 11.85892391, 12.46887684, 12.03547478, 18.76413727,
#        16.7736187 , 17.72440147,  9.11838722, 18.38789177, 21.58143234,
#        17.29642296, 19.29797363, 12.48949432, 11.67551899, 15.81113338,
#        11.22583008, 10.88896179, 17.29483986, 14.06724072, 18.07958603,
# ...

# %%
plt.plot(gamma[-1,1:100])

# %%
plt.plot(lag_gamma[-1,1:100])
